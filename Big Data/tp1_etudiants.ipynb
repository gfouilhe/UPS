# %%
import numpy as np
import matplotlib.pyplot as plt
import math as Math

# %%
# A remplir

# %%
l=100
m = 5000
p=5
[g,s] = ensalea(4,0.3,1)
x,y = echant(l,g,s)
plot_echant(x,y)
B,Re = estens(x,y,p)
plot_B(B)
display(Re)
Xtest,Ytest = echant(m,g,s)
display(testens(B,Xtest,Ytest))
# Out:
# 0.06
# 0.1134

# %%
# A remplir
# Out:
# Pour l=100 : le p optimal vaut :6
# Pour l=500 : le p optimal vaut :10
# Pour l=1000 : le p optimal vaut :15
# Pour l=10000 : le p optimal vaut :40
